# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv')
df.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
quantitative_list=['LotFrontage','LotArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','MiscVal','PoolArea','ScreenPorch','3SsnPorch','EnclosedPorch','OpenPorchSF','WoodDeckSF','GarageArea','GarageCars','Fireplaces','TotRmsAbvGrd','KitchenQual','HalfBath','FullBath','BsmtHalfBath','BsmtFullBath']
#this list has some column names to be added.

# %%
categorical = df.select_dtypes(include = 'object').copy()
categorical.shape
# Out:
# (1460, 43)

# %%
categorical.head(5)
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
#Lets treat missing values first
categorical.isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# ...

# %%
categorical.loc[categorical['Alley'].isnull(),'Alley']='None'

# %%
categorical.loc[categorical['BsmtQual'].isnull(),'BsmtQual']='None3'
categorical.loc[categorical['BsmtCond'].isnull(),'BsmtCond']='None4'
categorical.loc[categorical['BsmtExposure'].isnull(),'BsmtExposure']='None5'
categorical.loc[categorical['BsmtFinType1'].isnull(),'BsmtFinType1']='None6'
categorical.loc[categorical['BsmtFinType2'].isnull(),'BsmtFinType2']='None7'

# %%
categorical.loc[categorical['Electrical'].isnull(),'Electrical']='None1'
categorical.loc[categorical['MasVnrType'].isnull(),'MasVnrType']='None2'

# %%
categorical.loc[categorical['FireplaceQu'].isnull(),'FireplaceQu']='Nothing'
categorical.loc[categorical['GarageType'].isnull(),'GarageType']='No garage'
categorical.loc[categorical['GarageFinish'].isnull(),'GarageFinish']='None applicable'
categorical.loc[categorical['GarageQual'].isnull(),'GarageQual']='Not'
categorical.loc[categorical['GarageCond'].isnull(),'GarageCond']='Not applicable'

# %%
categorical.loc[categorical['PoolQC'].isnull(),'PoolQC']='None8'
categorical.loc[categorical['Fence'].isnull(),'Fence']='None9'
categorical.loc[categorical['MiscFeature'].isnull(),'MiscFeature']='None10'


#So no missing values in the categorical datframe.And missing values are because of a specific reason of not holding.

# %%
categorical.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
x=0
categorical['SalePrice']=df['SalePrice']
while x<43:
  #  categorical.iloc[:,x].value_counts().plot(kind='bar')
    abcd=categorical.columns[x]
    categorical.boxplot(column='SalePrice',by=abcd)
    x=x+1
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#so we have the dependency for the following columns by seeing the graphs above.
dependency_list=['MSZoning','Street','Alley','Neighborhood','Condition1','Condition2','RoofMatl','Exterior1st','Exterior2nd',
                'MasVnrType','ExterQual','FireplaceQu','GarageQual','PoolQC','MiscFeature','SaleType','SaleCondition',
                'SalePrice']



categorical2=categorical[dependency_list].copy()
categorical2.shape
# Out:
# (1460, 18)

# %%
x=0
while x<17:
  #  categorical2.iloc[:,x].value_counts().plot(kind='bar')
    abcd=categorical2.columns[x]
    categorical.boxplot(column='SalePrice',by=abcd)
    x=x+1
#So my hypothesis would be building on these 17 categorical features.

# %%
#Let us create dummies for inserting into the model.



#the ordinal categorical variables are 'ExterQual','GarageQual','FireplaceQu','PoolQC'. 

#categorical2[categorical2['ExterQual']=='Po']. so none of them has po let us ignore it.
map1={'TA':1,'Gd':2,'Ex':3,'Fa':0}
categorical2['Extermap']=categorical2['ExterQual'].map(map1)


map2={'TA':3,'Gd':4,'Ex':5,'Fa':2,'Not':0,'Po':1}
categorical2['Garagemap']=categorical2['GarageQual'].map(map2)

map3={'None8':0,'Gd':2,'Ex':3,'Fa':1}
categorical2['Poolmap']=categorical2['PoolQC'].map(map3)

map4={'TA':3,'Gd':4,'Ex':5,'Fa':2,'Po':1,'Nothing':0}
categorical2['Firemap']=categorical2['FireplaceQu'].map(map4)

# %%
#lets do the other part
List=['MSZoning', 'Street', 'Alley', 'Neighborhood', 'Condition1',
       'Condition2', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
         'MiscFeature',
       'SaleType', 'SaleCondition']
categorical3=categorical2[List].copy()

categorical4=pd.get_dummies(categorical3,List)

categorical5=categorical2[['Extermap','Garagemap','Poolmap','Firemap']].copy()

#categorical5 and categorical4 have the required values.

# %%
numerical = df.select_dtypes(exclude = 'object').copy()

categorical_in_numerical=['MSSubClass'] #this will be treated later.

numerical.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
numerical1=numerical['MSSubClass'].copy()

numerical2=pd.get_dummies(numerical1,categorical_in_numerical)


#so rest of the features are to be cleaned in the numerical dataframe.

# %%
#numerical.isnull().sum()
#missing values in lotfrontage and garage year built and masvnrarea.

# %%
numerical['LotFrontage'].fillna(0,axis=0,inplace=True)
numerical['MasVnrArea'].fillna(0,axis=0,inplace=True)

# %%
#numerical[numerical['GarageYrBlt'].isnull()].GarageYrBlt
b=numerical['GarageYrBlt'].mode()
numerical['GarageYrBlt'].fillna(value=2005.0,axis=0,inplace=True)
#ALL MISSING VALUES DEALT.

# %%
np.corrcoef(numerical['GarageYrBlt'].values, numerical['SalePrice'].values)
#a weak relationship
# Out:
# array([[1.        , 0.39777804],
#        [0.39777804, 1.        ]])

# %%
corr_df=numerical[[ 'LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold', 'SalePrice']].corr()
corr_df.shape
# Out:
# (35, 35)

# %%
corr_df=corr_df.loc[:,'SalePrice']

# %%
x=2
while x <38:
    plt.scatter(numerical.iloc[:,x].values,numerical['SalePrice'].values)
    plt.xlabel(numerical.columns[x])
    plt.show()
    x=x+1
#befor checking these let us check for outliers and variable transformation.These graphs are done after variable
#transformation.

# %%
#we need to check for variables whether they have normal distribution or not.
y=2
while y<38:
    plt.hist(numerical.iloc[:,y].values)
    plt.xlabel(numerical.columns[y])
    plt.show()
    y=y+1

# %%
y=numerical['SalePrice'].values
x1=np.log(1+numerical['LotFrontage'].values)
x2=np.log(1+numerical['MasVnrArea'].values)
x3=np.log(1+numerical['BsmtFinSF1'].values)
x4=np.log(1+numerical['BsmtUnfSF'].values)
x5=np.log(1+numerical['LotFrontage'].values)
x6=np.log(1+numerical['2ndFlrSF'].values)
x7=np.log(1+numerical['BsmtFullBath'].values)
x8=np.log(1+numerical['WoodDeckSF'].values)
x9=np.log(1+numerical['OpenPorchSF'].values)

# %%
numerical['LotFrontage']=x1
numerical['MasVnrArea']=x2
numerical['BsmtFinSF1']=x3
numerical['BsmtUnfSF']=x4
numerical['LotFrontage']=x5
numerical['2ndFlrSF']=x6
numerical['BsmtFullBath']=x7
numerical['WoodDeckSF']=x8
numerical['OpenPorchSF']=x9

# %%
numerical.head(5)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60     4.189655     8450            7            5       2003
# 1   2          20     4.394449     9600            6            8       1976
# 2   3          60     4.234107    11250            7            5       2001
# 3   4          70     4.110874     9550            7            5       1915
# 4   5          60     4.442651    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003    5.283204    6.561031  ...    0.000000     4.127134
# 1          1976    0.000000    6.886532  ...    5.700444     0.000000
# 2          2002    5.093750    6.188264  ...    0.000000     3.761200
# 3          1970    0.000000    5.379897  ...    0.000000     3.583519
# 4          2000    5.860786    6.486161  ...    5.262690     4.442651
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
numerical3=numerical[['LotFrontage', 'LotArea', 'OverallQual',
       'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
       'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'MoSold', 'YrSold']].copy()
numerical4=pd.concat([numerical3,numerical2],axis=1)
#numerical4(last columns have the categorical data at last) are the values of numerical data.
#categorical4 and categorical5 have the required categorical information.
cat_data=pd.concat([categorical5,categorical4,numerical2],axis=1)


# so finally numerical3 and cat_data have nmerical and categorical data respectively

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
a=cat_data.columns #135 columns of categorical data and 34 columns of numerical data.

# %%
scaler=StandardScaler()
cat_data=cat_data.astype('float64')
b=a.tolist()
cat_data[b] = scaler.fit_transform(cat_data[b])

#all the categorical data is standard scaled.

# %%
j=numerical3.columns
g=j.tolist()
numerical3=numerical3.astype('float64')
numerical3[g]=scaler.fit_transform(numerical3[g])

X_df=pd.concat([numerical3,cat_data],axis=1)
#all the numerical data is scaled.

# %%
#df['SalePrice']=df['SalePrice'].astype('float64')
#df[['SalePrice']]=scaler.fit_transform(df[['SalePrice']])

# %%
#Instead of using train for training my data I am using a portion of data set for train and the other portion for testing of 
# dataset.

# %%
#X_df contains all the X features
Y_df=df[['SalePrice']]
#Y_df contains all the Y features

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_df,Y_df)

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
e=np.asanyarray(X_train)
v=np.asanyarray(y_train)
regr.fit(e,v)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
w=np.asanyarray(X_test)
l=np.asanyarray(y_test)
l_hat=regr.predict(w)

# %%
print("Residual sum of squares: %.2f"% np.mean((l_hat - l) ** 2))
from sklearn.metrics import r2_score
r2=r2_score(l,l_hat)
print('R-square Score:', r2)
# Out:
# Residual sum of squares: 1304685182675539916884830846976.00
# R-square Score: -2.66917485651233e+20

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

XXX_DATA=PolynomialFeatures(degree = 2).fit_transform(e)
model = LinearRegression()
model.fit(XXX_DATA,v)

XXX1_DATA=PolynomialFeatures(degree = 2).fit_transform(w)
YYY1_DATA=model.predict(XXX1_DATA)

# %%
r2 = r2_score(YYY1_DATA,l)
print('R-square Score:', r2)

#an average r2 score for polynomial regression for training data as divided before.But it is quite better than the linear
#regression.But we have a pretty bad linear algo working. S the data is a polynomial regression and hence it is done
# Out:
# R-square Score: 0.5216748793265631
